# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# #### 1. Loading data
# Given the huge size of the dataset, we are loading first 500k reviews for the analysis.

# %%
reviews_df = pd.read_csv("yelp_review.csv", nrows=1000000)

# %% [markdown]
# #### 2. Data cleaning
# To get the best results, we are cleaning up the `text` column of the reviews dataset to get rid of non-alphabetic characters.

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text) 
    return text

reviews_df['cleaned_text'] = reviews_df['text'].apply(clean_text)

# %% [markdown]
# #### 3. Data pre-processing
# We are setting up the sentiment boundaries. Anything below 3 star is classified as negative and given value 0 and any reviews with 4 stars or more is classified as positive and given value 1. Anything in between is classified as None.
#
# In summary:
# - Stars >= 4: 1 - Positive review
# - Starts <= 2: 0 - Negative review
# - Else: None
#
# Finally, all the reviews with above None values are removed as this is irrelevant in our further analysis.

# %%
reviews_df['sentiment'] = reviews_df['stars'].apply(lambda x: 0 if x <= 2 else (1 if x >= 4 else None))
reviews_df = reviews_df.dropna(subset=['sentiment'])

# %% [markdown]
# #### 4. Model training
# Now a regression model is trained on the above data. The data is vectorized with TF-IDF vectorized before it is fed to the model for training.

# %%
X = reviews_df['cleaned_text']
y = reviews_df['sentiment']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=111)

tfidf_vectorizer = TfidfVectorizer(max_features=10000, stop_words='english')
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_test_tfidf = tfidf_vectorizer.transform(X_test)

model = LogisticRegression(max_iter=1000, random_state=111)
model.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=111)

# %% [markdown]
# #### 5. Model evaluation
# Once the model is trained, we have to evaluate the performance.

# %%
y_pred = model.predict(X_test_tfidf)
print(classification_report(y_test, y_pred))

conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Positive', 'Negative'], yticklabels=['Positive', 'Negative'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.88      0.90     44911
#          1.0       0.96      0.97      0.97    132279
#
#     accuracy                           0.95    177190
#    macro avg       0.94      0.93      0.93    177190
# weighted avg       0.95      0.95      0.95    177190

# %% [markdown]
# The model manages to produce a good accuracy score of 95%

# %% [markdown]
# #### Results
# Now we have the predictions, we can have a quick look the most features 50 keywords in both positive and negative reviews.

# %%
feature_names = np.array(tfidf_vectorizer.get_feature_names_out())
coefficients = model.coef_[0]

positive_indices = np.argsort(coefficients)[-50:]
negative_indices = np.argsort(coefficients)[:50] 

top_positive_keywords = feature_names[positive_indices]
top_negative_keywords = feature_names[negative_indices]

positive_scores = coefficients[positive_indices]
negative_scores = coefficients[negative_indices]

print("Top 50 Positive Keywords:")
print(list(zip(top_positive_keywords, positive_scores)))

print("\nTop 50 Negative Keywords:")
print(list(zip(top_negative_keywords, negative_scores)))

plt.figure(figsize=(8, 10))
plt.barh(top_positive_keywords, positive_scores, color='green')
plt.xlabel('Coefficient Value')
plt.title('Top 50 Positive Keywords')
plt.show()


plt.figure(figsize=(8, 10))
plt.barh(top_negative_keywords, negative_scores, color='red')
plt.xlabel('Coefficient Value')
plt.title('Top 50 Negative Keywords')
plt.show()
# Out:
# Top 50 Positive Keywords:
# [('superb', 5.537125014296352), ('refreshing', 5.698457596184673), ('reasonably', 5.929558512630875), ('happy', 5.956020881085865), ('exceptional', 5.992707413829987), ('yum', 6.019988911922305), ('easy', 6.048809557695849), ('solid', 6.124378432549599), ('heaven', 6.290600795963015), ('downside', 6.309864183429603), ('affordable', 6.310286985560352), ('professional', 6.326882276006457), ('satisfied', 6.327068437654578), ('fabulous', 6.397917918806208), ('glad', 6.408779658459565), ('disappoint', 6.520159154324218), ('delish', 6.606622510826184), ('helpful', 6.613084468286967), ('bomb', 6.734153194533646), ('beat', 6.738751980665982), ('reasonable', 6.898709396786415), ('gem', 6.928581318749102), ('thank', 7.074073713152884), ('good', 7.1153659465236725), ('pleased', 7.256663322541806), ('enjoyed', 7.34560942611636), ('yummy', 7.389475032063088), ('favorite', 7.426422219219217), ('knowledgeable', 7.701401341169275), ('outstanding', 7.7851577383279915), ('phenomenal', 7.785396375396971), ('notch', 7.827778778402912), ('pleasantly', 7.849518009991308), ('friendly', 7.854230789861169), ('perfection', 7.920464949683629), ('definitely', 8.396555622539104), ('loved', 8.52143936745982), ('wonderful', 8.907395259262083), ('perfectly', 9.124866314898636), ('highly', 9.168746528623505), ('incredible', 9.395624311914437), ('love', 10.456555727898959), ('best', 10.768992296577336), ('fantastic', 11.071146351010462), ('perfect', 11.885879586996717), ('awesome', 12.026732745081942), ('excellent', 12.264936469441356), ('great', 14.240895269781642), ('delicious', 14.422867588997338), ('amazing', 14.546441925454905)]
#
# Top 50 Negative Keywords:
# [('worst', -14.552876994013868), ('mediocre', -11.167294095124074), ('disappointing', -10.638798239481634), ('bland', -10.51268102566447), ('horrible', -10.507258106949168), ('disappointment', -9.913593250085992), ('terrible', -9.888539608507218), ('tasteless', -9.873064101300683), ('meh', -9.715019997387481), ('rude', -9.417156036544698), ('disgusting', -9.16287337179319), ('awful', -8.951214191501778), ('unprofessional', -8.942490765615785), ('subpar', -8.423622516415618), ('poisoning', -8.366706243541483), ('worse', -8.326084316075118), ('poor', -8.112947589053858), ('poorly', -7.7904670725567735), ('overpriced', -7.748627693877721), ('downhill', -7.602467225844613), ('zero', -7.458222387631116), ('lacked', -7.3989020782755786), ('flavorless', -7.341831054185224), ('unacceptable', -7.1185414922636), ('waste', -7.083379518363514), ('dry', -6.743287156750756), ('gross', -6.6106072370197), ('undercooked', -6.573103545396749), ('disappointed', -6.520674804049145), ('ok', -6.51878574301429), ('stale', -6.406783127157571), ('underwhelming', -6.380686738400545), ('ridiculous', -6.33791666873018), ('inedible', -6.276156568568896), ('edible', -6.250940977588921), ('refused', -6.235111345740047), ('overcooked', -6.167458667680461), ('sucks', -6.133623909191835), ('ignored', -6.042856640835803), ('barely', -6.0286119559773335), ('scam', -5.999842409684119), ('sorry', -5.990297724038652), ('overrated', -5.984128885829503), ('uncomfortable', -5.978659375500942), ('lacking', -5.956375807047894), ('slowest', -5.950386633757694), ('hopes', -5.872115589435202), ('rip', -5.864317246454259), ('unfortunately', -5.81499711063717), ('nicht', -5.775498791644921)]

# %% [markdown]
# #### 6. Analysis
#
# Lets take Top Ten Best Reviewed Business in Toronto.
#
# We list the Top Ten business in Toronto giving importance to the number of reviews and then to the number of stars obtained by the business.

# %%
business_df = pd.read_csv("yelp_business.csv")
business_df.head()
# Out:
#               business_id                        name neighborhood  \
# 0  FYWN1wneV18bWNgQjJ2GNg          "Dental by Design"          NaN
# 1  He-G7vWjzVUysIKrfNbPUQ       "Stephen Szabo Salon"          NaN
# 2  KQPW8lFf1y5BT2MxiSZ3QA     "Western Motor Vehicle"          NaN
# 3  8DShNS-LuFqpEWIp0HxijA          "Sports Authority"          NaN
# 4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"          NaN
#
#                             address            city state postal_code  \
# 0        "4855 E Warner Rd, Ste B9"       Ahwatukee    AZ       85044
# 1              "3101 Washington Rd"        McMurray    PA       15317
# 2          "6025 N 27th Ave, Ste 1"         Phoenix    AZ       85017
# 3  "5000 Arizona Mills Cr, Ste 435"           Tempe    AZ       85282
# 4                    "581 Howe Ave"  Cuyahoga Falls    OH       44221
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  33.330690 -111.978599    4.0            22        1
# 1  40.291685  -80.104900    3.0            11        1
# 2  33.524903 -112.115310    1.5            18        1
# 3  33.383147 -111.964725    3.0             9        0
# 4  41.119535  -81.475690    3.5           116        1
#
#                                           categories
# 0  Dentists;General Dentistry;Health & Medical;Or...
# 1  Hair Stylists;Hair Salons;Men's Hair Salons;Bl...
# 2  Departments of Motor Vehicles;Public Services ...
# 3                            Sporting Goods;Shopping
# 4  American (New);Nightlife;Bars;Sandwiches;Ameri...

# %%
# Filter businesses located in Toronto
toronto_review = business_df[business_df["city"] == "Toronto"]

# Sort by 'review_count' and 'stars' in descending order
toronto_review = toronto_review.sort_values(by=["review_count", "stars"], ascending=[False, False])

# Get the top 10 best review businesses
toronto_best_review_business = toronto_review.head(10)
display(toronto_best_review_business)

# Get the top 10 poor review businesses
toronto_poor_review_business = toronto_review[toronto_review["stars"] == 1].sort_values(by=["review_count"], ascending= [False])
toronto_poor_review_business = toronto_poor_review_business.head(10)
display(toronto_poor_review_business)
# Out:
#                    business_id                                 name  \
# 107580  r_BrIgzYcwo1NAuG9dLbpg          "Pai Northern Thai Kitchen"
# 158973  aLcFhMe6DDJ430zelCpd2A                      "Khao San Road"
# 9526    RtUvSWO_UZ8V3Wpj0n077w             "KINKA IZAKAYA ORIGINAL"
# 131553  N93EYZy9R0sdlEvubu94ig                       "Banh Mi Boys"
# 80828   iGEvDk6hsizigmXhDKs2Vg       "Seven Lives Tacos Y Mariscos"
# 5191    RwRNR4z3kY-4OsFqigY5sw  "Uncle Tetsu's Japanese Cheesecake"
# 49153   -av1lZI1JDY_RZN2eTMnWg              "Salad King Restaurant"
# 110247  zgQHtqX0gqMw1nlBZl2VnQ                "Momofuku Noodle Bar"
# 68285   uAAWlLdsoUf872F1FKiX1A     "Bang Bang Ice Cream and bakery"
# 36440   f5O7v_X_jCg2itqacRfxhg                     "Sansotei Ramen"
#
#                   neighborhood                                address  \
# 107580  Entertainment District                     "18 Duncan Street"
# 158973  Entertainment District                      "11 Charlotte St"
# 9526             Downtown Core                        "398 Church St"
# 131553       Queen Street West                   "392 Queen Street W"
# 80828        Kensington Market                 "69 Kensington Avenue"
# 5191             Downtown Core                       "598 Bay Street"
# 49153            Downtown Core                     "340 Yonge Street"
# 110247      Financial District  "190 University Avenue, Ground Floor"
# 68285          Ossington Strip                 "93a Ossington Avenue"
# 36440            Downtown Core                  "179 Dundas Street W"
#
#            city state postal_code   latitude  longitude  stars  review_count  \
# 107580  Toronto    ON     M5H 3G8  43.647866 -79.388642    4.5          1494
# 158973  Toronto    ON     M5V 2H5  43.646411 -79.393480    4.0          1270
# 9526    Toronto    ON     M5B 2A2  43.660524 -79.378927    4.0          1184
# 131553  Toronto    ON     M5V 2A9  43.648827 -79.396970    4.0           973
# 80828   Toronto    ON     M5T 2K2  43.654341 -79.400480    4.5           945
# 5191    Toronto    ON     M5G 1M5  43.655969 -79.384013    3.5           848
# 49153   Toronto    ON     M5B 1R8  43.657648 -79.381728    3.5           808
# 110247  Toronto    ON     M5H 0A3  43.649678 -79.386275    3.0           759
# 68285   Toronto    ON     M6J 2Z2  43.646286 -79.419474    4.0           746
# 36440   Toronto    ON     M5G 1Z8  43.655004 -79.386473    4.0           701
#
#         is_open                                         categories
# 107580        1   Food;Ethnic Food;Specialty Food;Restaurants;Thai
# 158973        1                                   Thai;Restaurants
# 9526          1  Tapas Bars;Japanese;Nightlife;Tapas/Small Plat...
# 131553        1  Vietnamese;Delicatessen;Asian Fusion;Restauran...
# 80828         1                        Mexican;Restaurants;Seafood
# 5191          1        Food;Desserts;Bakeries;Japanese;Restaurants
# 49153         1                                   Restaurants;Thai
# 110247        1  American (New);Ramen;Asian Fusion;Restaurants;...
# 68285         1            Food;Desserts;Ice Cream & Frozen Yogurt
# 36440         1                 Ramen;Japanese;Restaurants;Noodles
#                    business_id                              name  \
# 156361  Gglsm0mtG3PI8BzTvOm3zg                   "NU Car Rental"
# 27373   bIioipKX2IiES22VDFsytQ                       "Deal Find"
# 79380   LgrGYXtuwumUODemA66VGQ                      "Royal Taxi"
# 84048   XuS_k7rrv8VTvu2defcPTQ         "Trans Canada Car Rental"
# 29127   -6c_bJblLXUwoWfmYLtH_w          "Neo-Paws International"
# 15685   4YVCTg53T7xRkFF4yKVj6Q           "One A Minute Car Wash"
# 53145   AyuE2AyyKSZj97SNLAHM9w                          "Sbarro"
# 21380   D42mATIRcXGytmwycgaXew  "Stitch it Clothing Alterations"
# 120666  v6n7iPus9739N0VHR_v2rQ             "Stori Aperitivo Bar"
# 52772   ZrL5p18qbu-Ep9zU4YoEtw                     "Wrap & Roll"
#
#          neighborhood                                   address     city  \
# 156361      Etobicoke                          "801 Dixon Road"  Toronto
# 27373             NaN                       "250 Ferrand Drive"  Toronto
# 79380             NaN                     "2075 Bayview Avenue"  Toronto
# 84048       Etobicoke                          "801 Dixon Road"  Toronto
# 29127       Etobicoke             "2131 Lake Shore Boulevard W"  Toronto
# 15685             NaN                           "822 Church St"  Toronto
# 53145   Downtown Core  "Toronto Eaton Center, 220 Yonge Street"  Toronto
# 21380       Yorkville            "55 Bloor Street West, Unit 3"  Toronto
# 120666   St. Lawrence                        "95 King Street E"  Toronto
# 52772   Downtown Core                        "519 Yonge Street"  Toronto
#
#        state postal_code   latitude  longitude  stars  review_count  is_open  \
# 156361    ON     M9W 1J5  43.686875 -79.587150    1.0            27        1
# 27373     ON         M3C  43.719474 -79.331912    1.0            24        1
# 79380     ON     M4N 3M5  43.721704 -79.376008    1.0            22        1
# 84048     ON     M9W 1J5  43.687863 -79.586362    1.0            22        1
# 29127     ON     M8V 0B3  43.626932 -79.478738    1.0            17        1
# 15685     ON     M4W 2M9  43.672087 -79.385849    1.0            15        1
# 53145     ON     M5B 2H1  43.655442 -79.381671    1.0            15        1
# 21380     ON     M4W 1A1  43.669921 -79.389119    1.0            14        1
# 120666    ON     M5C 1G3  43.649807 -79.374792    1.0            12        1
# 52772     ON     M4Y 1Y3  43.663646 -79.384006    1.0            11        0
#
#                                                categories
# 156361                         Hotels & Travel;Car Rental
# 27373                           Shopping;Wholesale Stores
# 79380                Hotels & Travel;Taxis;Transportation
# 84048                          Hotels & Travel;Car Rental
# 29127   Pet Stores;Pets;Pet Services;Pet Groomers;Pet ...
# 15685      Auto Detailing;Car Wash;Auto Repair;Automotive
# 53145      Restaurants;Italian;Fast Food;Food Court;Pizza
# 21380                 Sewing & Alterations;Local Services
# 120666  Cocktail Bars;Bars;Dance Clubs;Restaurants;Ita...
# 52772                           Restaurants;Mediterranean

# %% [markdown]
# #### 6. Topic Modelling
#
# Lets take the first "Pai Northern Thai Kitchen" in top best review business

# %%
# Deep learning
import tensorflow_hub as hub

# Hugging Face
from transformers import pipeline

# Scikit-learn
from sklearn.cluster import KMeans

# NLP
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords

import warnings
warnings.filterwarnings('ignore')

# %%
# Download some nltk required data
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\aakas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aakas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Universal sentence encoder (from Google)
USE_encoder = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# Function to use USE encoder
def embed(input):
    return np.array(USE_encoder(input))

# %%
# Get sentiment model from hugging face platform

sentiment_model = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
def sentiment(input):
    result = sentiment_model(input[:512])
    sign = 1 if(result[0]['label']=="POSITIVE") else -1
    value = result[0]['score']
    return sign*value

# %%
reviews_df.shape
# Out:
# (885948, 11)

# %%
pai_thai_reviews = reviews_df[reviews_df['business_id'] == 'r_BrIgzYcwo1NAuG9dLbpg']['text'].dropna().tolist()
len(pai_thai_reviews)
# Out:
# 284

# %%
class ReviewsTopicModel:

    STOPWORDS = stopwords.words('english') # stopwords from ntlk

    EMBEDDING_DIM = 512 # USE encoder

    # Constructor
    def __init__(self, reviews):
        self.X = self.clean(reviews)

    # Clean text method
    def clean(self, reviews):
        # Words to replace
        string_map = {'\r': '', '\n': '', '/': ' ', "'": "", '"': ''}
        reviews_cleaned = reviews[:]
        for i in range(len(reviews_cleaned)):
            for s in string_map:
                reviews_cleaned[i] = reviews_cleaned[i].replace(s, string_map[s]).lower() 
        # Transform the reviews into embeddings dataframe
        X = embed(reviews_cleaned)
        X = pd.DataFrame(X)
        X.index = reviews_cleaned
        return X

    # Method to determine number of topics (a.k.a kmeans cluster number)
    def elbow_plot(self):
        cluster_sizes = list(range(1, 81))
        cluster_scores = []
        for n in cluster_sizes:
            kmeans = KMeans(n_clusters=n)
            kmeans.fit(self.X)
            cluster_scores.append(kmeans.inertia_)
        plt.figure()
        plt.plot(cluster_sizes, cluster_scores)
        plt.show()

    # Method to extract topics from text data
    def create_topics(self, num_topics):
        # Cluster the reviews
        kmeans = KMeans(n_clusters=num_topics)
        kmeans.fit(self.X)

        # Create the final topics dataframe
        topics_df = self.X.copy()
        topics_df['topic'] = kmeans.labels_.copy()
        topics_df['topic'] = topics_df['topic'].astype(int)

        # Create summary keywords per topic
        topic_keywords = {}
        for topic in topics_df['topic'].unique():
            topic_reviews = topics_df.query("topic == {}".format(topic)).index.tolist()
            topic_centroid = kmeans.cluster_centers_[topic] # cluster center
            topic_keywords[topic] = self.get_closest_words(topic_reviews, topic_centroid)
        topics_df['topic_keywords'] = topics_df['topic'].map(topic_keywords)

        # Score the sentiment of each review
        topics_df['sentiment'] = [sentiment(r) for r in topics_df.index.values.tolist()]

        # Final result
        self.topics_keywords = topic_keywords
        self.topics_df = topics_df.copy()[['topic', 'topic_keywords', 'sentiment']]


    def get_closest_words(self, reviews, centroid):
        word_distances = {}
        for r in reviews:
            review_words = [w for w in word_tokenize(r) if(w not in self.STOPWORDS)]
            for w in review_words:
                word_embedding = embed([w]) # return 512 dimensional vector for the word 'w'
                # how similar is the word embedding to the topic's centroid (avg of the cluster sample's embeddings)
                word_distances[w] = self.cosine_similarity(word_embedding, centroid) # 1 it means match, closer to 0 means different
        # done collecting the distances of the words to the topic's center
        top_5_keywords = sorted([(word_distances[w], w) for w in word_distances])[-5:]
        return ",".join([x[1] for x in top_5_keywords])

    def cosine_similarity(self, x, y):
        # x,y are both the appropriate dimension
        x = x.reshape(self.EMBEDDING_DIM,)
        y = y.reshape(self.EMBEDDING_DIM,)
        # calculate cosine similarity
        dotproduct = x.dot(y)
        x_mag = x.dot(x)**0.5
        y_mag = y.dot(y)**0.5
        # returns closer to 1 if x and y are similar, closer to 0 if they are different
        return dotproduct/(x_mag * y_mag)

# %%
topic_model = ReviewsTopicModel(pai_thai_reviews)

# %%
topic_model.elbow_plot() # going to use 40 clusters i.e. 40 topics

# %%
topic_model.create_topics(num_topics=40)

# %%
topic_model.topics_df.query("topic == 35")
# Out:
#                                                     topic  \
# was there for a ny celebration and had a great ...     35
# its good food service was quick and they care a...     35
# as good as everybody has said it is! nice relax...     35
#
#                                                                                     topic_keywords  \
# was there for a ny celebration and had a great ...  dishes,affordable,reasonable,customer,flavours
# its good food service was quick and they care a...  dishes,affordable,reasonable,customer,flavours
# as good as everybody has said it is! nice relax...  dishes,affordable,reasonable,customer,flavours
#
#                                                     sentiment
# was there for a ny celebration and had a great ...   0.999883
# its good food service was quick and they care a...   0.999750
# as good as everybody has said it is! nice relax...   0.999866

# %%
topic_model.topics_df.groupby(['topic', 'topic_keywords']).agg({'sentiment': 'mean'}).reset_index()\
    .sort_values(by='sentiment')
# Out:
#     topic                                  topic_keywords  sentiment
# 18     18          dining,rude,restaraunt,gratuity,waiter  -0.998993
# 38     38              compared,flavours,san,shorter,khao  -0.998916
# 20     20                    chang,drank,nikki,drinks,bae  -0.992813
# 22     22                  dinner,pork,bbq,sandwich,lunch   0.030650
# 19     19                   soup,shrimp,noodles,khao,thai   0.331510
# 27     27                  thailand,satay,thais,khao,thai   0.440452
# 26     26               shrimps,menu,thai,appetizers,khao   0.490858
# 17     17                  farang,curries,satay,khao,thai   0.511585
# 0       0               braised,thailand,farang,khao,thai   0.589068
# 34     34                    menu,braised,khao,satay,thai   0.607963
# 1       1              ordering,ordered,tempura,thai,khao   0.657248
# 15     15               delish,coconut,curry,thai,curries   0.667354
# 7       7            curry,coriander,lemongrass,khao,thai   0.700464
# 5       5              authentic,thaïlande,thaï,khao,thai   0.712417
# 28     28                   curry,khao,thai,thai\,curries   0.736406
# 3       3             thailand,tamarind,curries,khao,thai   0.743343
# 12     12                currys,chiang,thailand,khao,thai   0.767488
# 36     36                 takeout,curries,thais,khao,thai   0.808577
# 8       8                  thailand,thais,khao,thai,thai-   0.850126
# 23     23               chiang,curries,thailand,khao,thai   0.893953
# 25     25                     pai,lime,curry,thai,coconut   0.906596
# 29     29                 wednesday,blame,pad,thai,packed   0.970925
# 10     10                time,ahead,best,busy,reservation   0.994322
# 39     39                seated,fast,service,skip,dessert   0.995701
# 16     16             ordered,went,table,portions,service   0.998273
# 21     21         restaurants,resturant,toronto,khao,thai   0.998335
# 30     30             capacity,mingling,attended,open,bar   0.998464
# 14     14                      tell,monster,mom,dad,wings   0.999067
# 2       2                 loud,arranged,seating,khao,thai   0.999367
# 13     13               noodles,tables,order,table,waiter   0.999386
# 32     32                     great,spot,funky,salad,thai   0.999461
# 24     24                 peanuts,chicken,food,satay,thai   0.999523
# 6       6                  flavourful,food,menu,khao,thai   0.999600
# 9       9                  yummy,tofu,delish,braised,thai   0.999635
# 37     37          liked,warm,greeted,friendly,reasonable   0.999768
# 11     11           excellent,super,food,service,friendly   0.999799
# 35     35  dishes,affordable,reasonable,customer,flavours   0.999833
# 33     33                    taste,safe,food,vegan,celiac   0.999837
# 4       4            excellent,fantastic,dined,yummy,food   0.999845
# 31     31            food,lunch,meals,delicious,waitstaff   0.999875
